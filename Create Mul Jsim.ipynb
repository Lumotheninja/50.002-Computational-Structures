# %%
string = ""

for i in xrange(32):
    
    for j in xrange(32-i):
        print "Xa%db%d " % (j,i) + "A%d " % (j) + "B%d " % (i) + "a%db%d " % (j,i) + "and2"
        string = "a%db%d " % (j,i) + string
    string += "0#%d " % (i) + "multiply%da[31:0] " % (i)+ "multiply%da[31:0] " %(i+1) + "z%d v%d n%d " % (i,i,i) + "adder32"
    string = "Xid%d 0 " % (i) + string
    print string
    string = ""
# Out:
# Xa0b0 A0 B0 a0b0 and2
# Xa1b0 A1 B0 a1b0 and2
# Xa2b0 A2 B0 a2b0 and2
# Xa3b0 A3 B0 a3b0 and2
# Xa4b0 A4 B0 a4b0 and2
# Xa5b0 A5 B0 a5b0 and2
# Xa6b0 A6 B0 a6b0 and2
# Xa7b0 A7 B0 a7b0 and2
# Xa8b0 A8 B0 a8b0 and2
# Xa9b0 A9 B0 a9b0 and2
# Xa10b0 A10 B0 a10b0 and2
# Xa11b0 A11 B0 a11b0 and2
# Xa12b0 A12 B0 a12b0 and2
# Xa13b0 A13 B0 a13b0 and2
# Xa14b0 A14 B0 a14b0 and2
# Xa15b0 A15 B0 a15b0 and2
# Xa16b0 A16 B0 a16b0 and2
# Xa17b0 A17 B0 a17b0 and2
# Xa18b0 A18 B0 a18b0 and2
# Xa19b0 A19 B0 a19b0 and2
# Xa20b0 A20 B0 a20b0 and2
# Xa21b0 A21 B0 a21b0 and2
# Xa22b0 A22 B0 a22b0 and2
# Xa23b0 A23 B0 a23b0 and2
# Xa24b0 A24 B0 a24b0 and2
# Xa25b0 A25 B0 a25b0 and2
# Xa26b0 A26 B0 a26b0 and2
# Xa27b0 A27 B0 a27b0 and2
# Xa28b0 A28 B0 a28b0 and2
# Xa29b0 A29 B0 a29b0 and2
# Xa30b0 A30 B0 a30b0 and2
# Xa31b0 A31 B0 a31b0 and2
# ...
